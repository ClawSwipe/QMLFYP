# %%
# !pip install pennylane pennylane-lightning pennylane-lightning[gpu] --upgrade
# !pip install --upgrade "jax[cuda12_pip]" -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# Out:
# Collecting pennylane
#   Downloading PennyLane-0.37.0-py3-none-any.whl.metadata (9.3 kB)
# Collecting pennylane-lightning
#   Downloading PennyLane_Lightning-0.37.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (23 kB)
# Requirement already satisfied: numpy<2.0 in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from pennylane) (3.3)
# Collecting rustworkx (from pennylane)
#   Downloading rustworkx-0.15.1-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.9 kB)
# Requirement already satisfied: autograd in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.7.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from pennylane) (0.10.2)
# Collecting appdirs (from pennylane)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting semantic-version>=2.7 (from pennylane)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting autoray>=0.6.11 (from pennylane)
#   Downloading autoray-0.6.12-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from pennylane) (5.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pennylane) (2.32.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pennylane) (4.12.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from pennylane) (24.1)
# Collecting pennylane-lightning-gpu (from pennylane-lightning[gpu])
#   Downloading PennyLane_Lightning_GPU-0.37.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (2024.7.4)
# Downloading PennyLane-0.37.0-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 33.6 MB/s eta 0:00:00
# Downloading PennyLane_Lightning-0.37.0-cp310-cp310-manylinux_2_28_x86_64.whl (15.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.5/15.5 MB 81.7 MB/s eta 0:00:00
# Downloading autoray-0.6.12-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 3.7 MB/s eta 0:00:00
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading PennyLane_Lightning_GPU-0.37.0-cp310-cp310-manylinux_2_28_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 91.5 MB/s eta 0:00:00
# Downloading rustworkx-0.15.1-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 74.8 MB/s eta 0:00:00
# Installing collected packages: appdirs, semantic-version, rustworkx, autoray, pennylane-lightning, pennylane, pennylane-lightning-gpu
# Successfully installed appdirs-1.4.4 autoray-0.6.12 pennylane-0.37.0 pennylane-lightning-0.37.0 pennylane-lightning-gpu-0.37.0 rustworkx-0.15.1 semantic-version-2.10.0
# Looking in links: https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# Requirement already satisfied: jax[cuda12_pip] in /usr/local/lib/python3.10/dist-packages (0.4.26)
# Collecting jax[cuda12_pip]
#   Downloading jax-0.4.31-py3-none-any.whl.metadata (22 kB)
# Collecting jaxlib<=0.4.31,>=0.4.30 (from jax[cuda12_pip])
#   Downloading jaxlib-0.4.31-cp310-cp310-manylinux2014_x86_64.whl.metadata (983 bytes)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax[cuda12_pip]) (0.4.0)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.10/dist-packages (from jax[cuda12_pip]) (1.26.4)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax[cuda12_pip]) (3.3.0)
# Requirement already satisfied: scipy>=1.10 in /usr/local/lib/python3.10/dist-packages (from jax[cuda12_pip]) (1.13.1)
# Collecting jax-cuda12-plugin<=0.4.31,>=0.4.31 (from jax-cuda12-plugin[with_cuda]<=0.4.31,>=0.4.31; extra == "cuda12-pip"->jax[cuda12_pip])
#   Downloading jax_cuda12_plugin-0.4.31-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Collecting jax-cuda12-pjrt==0.4.31 (from jax-cuda12-plugin<=0.4.31,>=0.4.31->jax-cuda12-plugin[with_cuda]<=0.4.31,>=0.4.31; extra == "cuda12-pip"->jax[cuda12_pip])
#   Downloading jax_cuda12_pjrt-0.4.31-py3-none-manylinux2014_x86_64.whl.metadata (349 bytes)
# Collecting nvidia-cublas-cu12>=12.1.3.1 (from jax-cuda12-plugin[with_cuda]<=0.4.31,>=0.4.31; extra == "cuda12-pip"->jax[cuda12_pip])
#   Downloading nvidia_cublas_cu12-12.6.1.4-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12>=12.1.105 (from jax-cuda12-plugin[with_cuda]<=0.4.31,>=0.4.31; extra == "cuda12-pip"->jax[cuda12_pip])
#   Downloading nvidia_cuda_cupti_cu12-12.6.68-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cuda-nvcc-cu12>=12.1.105 (from jax-cuda12-plugin[with_cuda]<=0.4.31,>=0.4.31; extra == "cuda12-pip"->jax[cuda12_pip])
#   Downloading nvidia_cuda_nvcc_cu12-12.6.68-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12>=12.1.105 (from jax-cuda12-plugin[with_cuda]<=0.4.31,>=0.4.31; extra == "cuda12-pip"->jax[cuda12_pip])
#   Downloading nvidia_cuda_runtime_cu12-12.6.68-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cudnn-cu12<10.0,>=9.1 (from jax-cuda12-plugin[with_cuda]<=0.4.31,>=0.4.31; extra == "cuda12-pip"->jax[cuda12_pip])
#   Downloading nvidia_cudnn_cu12-9.3.0.75-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cufft-cu12>=11.0.2.54 (from jax-cuda12-plugin[with_cuda]<=0.4.31,>=0.4.31; extra == "cuda12-pip"->jax[cuda12_pip])
#   Downloading nvidia_cufft_cu12-11.2.6.59-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12>=11.4.5.107 (from jax-cuda12-plugin[with_cuda]<=0.4.31,>=0.4.31; extra == "cuda12-pip"->jax[cuda12_pip])
#   Downloading nvidia_cusolver_cu12-11.6.4.69-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12>=12.1.0.106 (from jax-cuda12-plugin[with_cuda]<=0.4.31,>=0.4.31; extra == "cuda12-pip"->jax[cuda12_pip])
#   Downloading nvidia_cusparse_cu12-12.5.3.3-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12>=2.18.1 in /usr/local/lib/python3.10/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.4.31,>=0.4.31; extra == "cuda12-pip"->jax[cuda12_pip]) (2.22.3)
# Collecting nvidia-nvjitlink-cu12>=12.1.105 (from jax-cuda12-plugin[with_cuda]<=0.4.31,>=0.4.31; extra == "cuda12-pip"->jax[cuda12_pip])
#   Downloading nvidia_nvjitlink_cu12-12.6.68-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Downloading jaxlib-0.4.31-cp310-cp310-manylinux2014_x86_64.whl (88.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.1/88.1 MB 8.8 MB/s eta 0:00:00
# Downloading jax_cuda12_plugin-0.4.31-cp310-cp310-manylinux2014_x86_64.whl (14.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 107.2 MB/s eta 0:00:00
# Downloading jax_cuda12_pjrt-0.4.31-py3-none-manylinux2014_x86_64.whl (84.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.2/84.2 MB 8.9 MB/s eta 0:00:00
# Downloading jax-0.4.31-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 80.6 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.6.1.4-py3-none-manylinux2014_x86_64.whl (378.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 378.9/378.9 MB 2.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.6.68-py3-none-manylinux2014_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 84.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvcc_cu12-12.6.68-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 59.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.6.68-py3-none-manylinux2014_x86_64.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 47.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.3.0.75-py3-none-manylinux2014_x86_64.whl (577.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 577.2/577.2 MB 3.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.6.59-py3-none-manylinux2014_x86_64.whl (192.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.5/192.5 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.4.69-py3-none-manylinux2014_x86_64.whl (130.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.5/130.5 MB 7.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.5.3.3-py3-none-manylinux2014_x86_64.whl (216.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.5/216.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.6.68-py3-none-manylinux2014_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 96.3 MB/s eta 0:00:00
# Installing collected packages: jax-cuda12-pjrt, nvidia-nvjitlink-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvcc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, jax-cuda12-plugin, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, jaxlib, nvidia-cusolver-cu12, jax
#   Attempting uninstall: jaxlib
#     Found existing installation: jaxlib 0.4.26+cuda12.cudnn89
#     Uninstalling jaxlib-0.4.26+cuda12.cudnn89:
#       Successfully uninstalled jaxlib-0.4.26+cuda12.cudnn89
#   Attempting uninstall: jax
#     Found existing installation: jax 0.4.26
#     Uninstalling jax-0.4.26:
#       Successfully uninstalled jax-0.4.26
# Successfully installed jax-0.4.31 jax-cuda12-pjrt-0.4.31 jax-cuda12-plugin-0.4.31 jaxlib-0.4.31 nvidia-cublas-cu12-12.6.1.4 nvidia-cuda-cupti-cu12-12.6.68 nvidia-cuda-nvcc-cu12-12.6.68 nvidia-cuda-runtime-cu12-12.6.68 nvidia-cudnn-cu12-9.3.0.75 nvidia-cufft-cu12-11.2.6.59 nvidia-cusolver-cu12-11.6.4.69 nvidia-cusparse-cu12-12.5.3.3 nvidia-nvjitlink-cu12-12.6.68

# %%
# Import packages
import matplotlib as mpl
import matplotlib.pyplot as plt
import sys
import numpy as np
#np.set_printoptions(threshold=sys.maxsize)
import pandas as pd
from sklearn import datasets
import seaborn as sns
import jax
import time
from tifffile import tifffile
import functools

from typing import List, Union, Tuple, Dict, Optional, Any
from typing import Callable

jax.config.update("jax_enable_x64", True)
#jax.config.update("jax_debug_nans", True)
import jax.numpy as jnp

import optax  # optimization using jax

import torch  # https://pytorch.org
import torchvision  # https://pytorch.org
#torch.set_printoptions(profile="full")
import pennylane as qml
import pennylane.numpy as pnp

import os, cv2, itertools # cv2 -- OpenCV
import shutil
import zipfile
# %matplotlib inline

from jax.lib import xla_bridge

def set_jax_platform():
    # Check if TPU is available
    try:
        tpu_backend = xla_bridge.get_backend('tpu')
        if tpu_backend and tpu_backend.device_count() > 0:
            # Set platform to TPU
            jax.config.update('jax_platform_name', 'tpu')
            print("Set platform to TPU")
            return
    except RuntimeError:
        pass  # No TPU found, move on to check for GPU

    # Check if GPU is available
    try:
      gpu_backend = xla_bridge.get_backend('gpu')
      if gpu_backend and gpu_backend.device_count() > 0:
          # Set platform to CUDA (GPU)
          jax.config.update('jax_platform_name', 'gpu')
          print("Set platform to GPU")
    except RuntimeError:
          # Set platform to CPU
          jax.config.update('jax_platform_name', 'cpu')
          print("Set platform to CPU")

# Call the function to set the platform
set_jax_platform()

sns.set()

seed = 1701
rng = np.random.default_rng(seed=seed)
prng = pnp.random.default_rng(seed=seed)
jrng_key = jax.random.PRNGKey(seed)
# Out:
# Set platform to GPU

# %%
def convolutional_layer(weights, wires, skip_first_layer=True):
    """Adds a convolutional layer to a circuit.
    Args:
        weights (np.array): 1D array with 15 weights of the parametrized gates.
        wires (list[int]): Wires where the convolutional layer acts on.
        skip_first_layer (bool): Skips the first two U3 gates of a layer.
    """
    n_wires = len(wires)
    assert n_wires >= 3, "this circuit is too small!"

    for p in [0, 1]:
        for indx, w in enumerate(wires):
            if indx % 2 == p and indx < n_wires - 1:
                if indx % 2 == 0 and not skip_first_layer:
                    qml.U3(*weights[:3], wires=[w])
                    qml.U3(*weights[3:6], wires=[wires[indx + 1]])
                qml.IsingXX(weights[6], wires=[w, wires[indx + 1]])
                qml.IsingYY(weights[7], wires=[w, wires[indx + 1]])
                qml.IsingZZ(weights[8], wires=[w, wires[indx + 1]])
                qml.U3(*weights[9:12], wires=[w])
                qml.U3(*weights[12:], wires=[wires[indx + 1]])

def pooling_layer(weights, wires):
    """Adds a pooling layer to a circuit.
    Args:
        weights (np.array): Array with the weights of the conditional U3 gate.
        wires (list[int]): List of wires to apply the pooling layer on.
    """
    n_wires = len(wires)
    assert len(wires) >= 2, "this circuit is too small!"

    for indx, w in enumerate(wires):
        if indx % 2 == 1 and indx < n_wires:
            m_outcome = qml.measure(w)
            qml.cond(m_outcome, qml.U3)(*weights, wires=wires[indx - 1])

def conv_and_pooling(kernel_weights, n_wires, skip_first_layer=True):
    """Apply both the convolutional and pooling layer."""
    convolutional_layer(kernel_weights[:15], n_wires, skip_first_layer=skip_first_layer)
    pooling_layer(kernel_weights[15:], n_wires)


def dense_layer(weights, wires):
    """Apply an arbitrary unitary gate to a specified set of wires."""
    qml.ArbitraryUnitary(weights, wires)


num_wires = 6
device = qml.device("default.qubit", wires=num_wires)


@qml.qnode(device)
def conv_net(weights, last_layer_weights, features):
    """Define the QCNN circuit
    Args:
        weights (np.array): Parameters of the convolution and pool layers.
        last_layer_weights (np.array): Parameters of the last dense layer.
        features (np.array): Input data to be embedded using AmplitudEmbedding."""

    layers = weights.shape[1]
    wires = list(range(num_wires))

    # inputs the state input_state
    qml.AmplitudeEmbedding(features=features, wires=wires, pad_with=0.5)
    qml.Barrier(wires=wires, only_visual=True)

    # adds convolutional and pooling layers
    for j in range(layers):
        conv_and_pooling(weights[:, j], wires, skip_first_layer=(not j == 0))
        wires = wires[::2]
        qml.Barrier(wires=wires, only_visual=True)

    assert last_layer_weights.size == 4 ** (len(wires)) - 1, (
        "The size of the last layer weights vector is incorrect!"
        f" \n Expected {4 ** (len(wires)) - 1}, Given {last_layer_weights.size}"
    )
    dense_layer(last_layer_weights, wires)
    return qml.probs(wires=(0, 2, 4))


fig, ax = qml.draw_mpl(conv_net)(
    np.random.rand(18, 1), np.random.rand(4 ** 3 - 1), np.random.rand(2 ** num_wires)
)
plt.show()

# %%
digits = datasets.load_digits()
images, labels = digits.data, digits.target

images = images[np.where((labels == 0) | (labels == 1)|(labels == 2) | (labels == 3)|(labels == 4) | (labels == 5)|(labels == 6) | (labels == 7))]
labels = labels[np.where((labels == 0) | (labels == 1)|(labels == 2) | (labels == 3)|(labels == 4) | (labels == 5)|(labels == 6) | (labels == 7))]

fig, axes = plt.subplots(nrows=1, ncols=16, figsize=(16, 1))

for i, ax in enumerate(axes.flatten()):
    ax.imshow(images[i].reshape((8, 8)), cmap="gray")
    ax.axis("off")

plt.tight_layout()
plt.subplots_adjust(wspace=0, hspace=0)
plt.show()

# %%
def load_digits_data(num_train, num_test, rng):
    """Return training and testing data of digits dataset."""
    digits = datasets.load_digits()
    features, labels = digits.data, digits.target

    features = features[np.where((labels == 0) | (labels == 1)|(labels == 2) | (labels == 3)|(labels == 4) | (labels == 5)|(labels == 6) | (labels == 7))]
    labels = labels[np.where((labels == 0) | (labels == 1)|(labels == 2) | (labels == 3)|(labels == 4) | (labels == 5)|(labels == 6) | (labels == 7))]

    # normalize data
    features = features / np.linalg.norm(features, axis=1).reshape((-1, 1))

    # subsample train and test split
    train_indices = rng.choice(len(labels), num_train, replace=False)
    test_indices = rng.choice(
        np.setdiff1d(range(len(labels)), train_indices), num_test, replace=False
    )

    x_train, y_train = features[train_indices], labels[train_indices]
    x_test, y_test = features[test_indices], labels[test_indices]

    return (
        jnp.asarray(x_train),
        jnp.asarray(y_train),
        jnp.asarray(x_test),
        jnp.asarray(y_test),
    )

# %%
@jax.jit
def compute_out(weights, weights_last, features, labels):
    """Computes the output of the corresponding label in the qcnn"""
    cost = lambda weights, weights_last, feature, label: conv_net(weights, weights_last, feature)
    return jax.vmap(cost, in_axes=(None, None, 0, 0), out_axes=0)(
        weights, weights_last, features, labels
    )


def compute_accuracy(weights, weights_last, features, labels):
    """Computes the accuracy over the provided features and labels"""
    out = compute_out(weights, weights_last, features, labels)
    pred = jnp.argmax(out, axis = 1)
    return jnp.sum(jnp.array(pred == labels).astype(int)) / len(out)


def compute_cost(weights, weights_last, features, labels):
    """Computes the cost over the provided features and labels"""
    logits = compute_out(weights, weights_last, features, labels)
    return jnp.mean(optax.softmax_cross_entropy_with_integer_labels(logits, labels))


def init_weights():
    """Initializes random weights for the QCNN model."""
    weights = pnp.random.normal(loc=0, scale=1, size=(18, 1), requires_grad=True)
    weights_last = pnp.random.normal(loc=0, scale=1, size=4 ** 3 - 1, requires_grad=True)
    return jnp.array(weights), jnp.array(weights_last)


value_and_grad = jax.jit(jax.value_and_grad(compute_cost, argnums=[0, 1]))

# %%
def batch_data(data, targets, batch_size):
    N = data.shape[0]
    for i in range(0, N, batch_size):
        yield data[i:i + batch_size], targets[i:i + batch_size]

def train_qcnn(n_train, n_test, n_epochs, batch_size = 100):
    """
    Args:
        n_train  (int): number of training examples
        n_test   (int): number of test examples
        n_epochs (int): number of training epochs
        desc  (string): displayed string during optimization

    Returns:
        dict: n_train,
        steps,
        train_cost_epochs,
        train_acc_epochs,
        test_cost_epochs,
        test_acc_epochs

    """
    # load data
    x_train, y_train, x_test, y_test = load_digits_data(n_train, n_test, rng)

    # init weights and optimizer
    weights, weights_last = init_weights()

    optimizer = optax.adam(learning_rate=0.1)
    opt_state = optimizer.init((weights, weights_last))

    # data containers
    train_cost_epochs, test_cost_epochs, train_acc_epochs, test_acc_epochs = [], [], [], []

    for step in range(n_epochs):
        epoch_start = time.time()
        print(f"Training at Epoch {step+1}/{n_epochs}, Train size {n_train}, Test size {n_test}......")
        # Training step with classical optimizer
        # batching
        batch_cost = []
        batch_acc = []
        for batch_id, (x, y) in enumerate(batch_data(x_train, y_train, batch_size)):
          batch_start = time.time()
          train_cost_batch, grad_circuit = value_and_grad(weights, weights_last, x, y)
          updates, opt_state = optimizer.update(grad_circuit, opt_state)
          weights, weights_last = optax.apply_updates((weights, weights_last), updates)

          batch_cost.append(train_cost_batch)

          # compute accuracy on training data
          train_acc_batch = compute_accuracy(weights, weights_last, x, y)
          batch_acc.append(train_acc_batch)
          print(f"Training at Epoch {step+1}/{n_epochs}, Batch {batch_id+1}, Cost {train_cost_batch}, Acc {train_acc_batch}. Time {time.time()-batch_start}")

        train_cost_epochs.append(np.mean(batch_cost))
        train_acc_epochs.append(np.mean(batch_acc))
        #print(f"Epoch {step+1}/{n_epochs}, Train: Cost {np.mean(batch_cost)}, Acc {np.mean(batch_acc)}")

        # compute accuracy and cost on testing data
        test_out = compute_out(weights, weights_last, x_test, y_test)
        test_pred = jnp.argmax(test_out, axis=1)
        test_acc = jnp.sum(jnp.array(test_pred == y_test).astype(int)) / len(test_out)
        test_acc_epochs.append(test_acc)
        test_cost = jnp.mean(optax.softmax_cross_entropy_with_integer_labels(test_out, y_test))
        #test_cost = jnp.mean(optax.softmax_cross_entropy_with_integer_labels(test_out, y_test))
        test_cost_epochs.append(test_cost)
        epoch_end = time.time()
        print(f"Epoch {step+1}/{n_epochs}, Train: Cost {np.mean(batch_cost)}, Acc {np.mean(batch_acc)}; Test: Cost {test_cost}, Acc {test_acc}. Time {time.time()-epoch_start}")
        print("=-="*10)
    return dict(
        n_train=[n_train] * n_epochs,
        step=np.arange(1, n_epochs + 1, dtype=int),
        train_cost=train_cost_epochs,
        train_acc=train_acc_epochs,
        test_cost=test_cost_epochs,
        test_acc=test_acc_epochs,
    )

# %%
n_test = 100
n_epochs = 500
n_reps = 20
batch_size = 2000

train_sizes = [1200]

def run_iterations(n_train):
    results_df = pd.DataFrame(
        columns=["train_acc", "train_cost", "test_acc", "test_cost", "step", "n_train"]
    )

    for _ in range(n_reps):
        results = train_qcnn(n_train=n_train, n_test=n_test, n_epochs=n_epochs, batch_size=batch_size)
        results_df = pd.concat(
            [results_df, pd.DataFrame.from_dict(results)], axis=0, ignore_index=True
        )

    return results_df

results_df = run_iterations(n_train=1200)
#for n_train in train_sizes[1:]:
#    results_df = pd.concat([results_df, run_iterations(n_train=n_train)])
# Out:
# Training at Epoch 1/500, Train size 1200, Test size 100......
# Training at Epoch 1/500, Batch 1, Cost 2.0782154731470053, Acc 0.2658333333333333. Time 28.177776098251343
# Epoch 1/500, Train: Cost 2.0782154731470053, Acc 0.2658333333333333; Test: Cost 2.0651465106412887, Acc 0.22. Time 32.09239077568054
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 2/500, Train size 1200, Test size 100......
# Training at Epoch 2/500, Batch 1, Cost 2.0607037945208386, Acc 0.3725. Time 0.15941452980041504
# Epoch 2/500, Train: Cost 2.0607037945208386, Acc 0.3725; Test: Cost 2.049833625549062, Acc 0.33. Time 0.16966938972473145
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 3/500, Train size 1200, Test size 100......
# Training at Epoch 3/500, Batch 1, Cost 2.043837629122801, Acc 0.5133333333333333. Time 0.10493659973144531
# Epoch 3/500, Train: Cost 2.043837629122801, Acc 0.5133333333333333; Test: Cost 2.036994622615486, Acc 0.52. Time 0.10959482192993164
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 4/500, Train size 1200, Test size 100......
# Training at Epoch 4/500, Batch 1, Cost 2.0354191080392505, Acc 0.48. Time 0.06667470932006836
# Epoch 4/500, Train: Cost 2.0354191080392505, Acc 0.48; Test: Cost 2.0291453469245737, Acc 0.5. Time 0.0728597640991211
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 5/500, Train size 1200, Test size 100......
# Training at Epoch 5/500, Batch 1, Cost 2.0290481899560056, Acc 0.485. Time 0.06614851951599121
# Epoch 5/500, Train: Cost 2.0290481899560056, Acc 0.485; Test: Cost 2.0261454716895666, Acc 0.47. Time 0.07117533683776855
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 6/500, Train size 1200, Test size 100......
# Training at Epoch 6/500, Batch 1, Cost 2.0255098917443655, Acc 0.47. Time 0.06291341781616211
# Epoch 6/500, Train: Cost 2.0255098917443655, Acc 0.47; Test: Cost 2.023500658999058, Acc 0.44. Time 0.06737327575683594
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 7/500, Train size 1200, Test size 100......
# Training at Epoch 7/500, Batch 1, Cost 2.023156952274404, Acc 0.43583333333333335. Time 0.06245779991149902
# Epoch 7/500, Train: Cost 2.023156952274404, Acc 0.43583333333333335; Test: Cost 2.0212371175378068, Acc 0.42. Time 0.06784343719482422
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 8/500, Train size 1200, Test size 100......
# Training at Epoch 8/500, Batch 1, Cost 2.0209271912204967, Acc 0.46166666666666667. Time 0.06215357780456543
# Epoch 8/500, Train: Cost 2.0209271912204967, Acc 0.46166666666666667; Test: Cost 2.018977597171843, Acc 0.47. Time 0.06655383110046387
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 9/500, Train size 1200, Test size 100......
# Training at Epoch 9/500, Batch 1, Cost 2.017970945397843, Acc 0.5341666666666667. Time 0.06194639205932617
# Epoch 9/500, Train: Cost 2.017970945397843, Acc 0.5341666666666667; Test: Cost 2.0173610315412245, Acc 0.48. Time 0.06767892837524414
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 10/500, Train size 1200, Test size 100......
# Training at Epoch 10/500, Batch 1, Cost 2.0156348939831967, Acc 0.5883333333333334. Time 0.06189393997192383
# Epoch 10/500, Train: Cost 2.0156348939831967, Acc 0.5883333333333334; Test: Cost 2.015528168257404, Acc 0.59. Time 0.06638717651367188
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 11/500, Train size 1200, Test size 100......
# Training at Epoch 11/500, Batch 1, Cost 2.012629333469582, Acc 0.6175. Time 0.0619053840637207
# Epoch 11/500, Train: Cost 2.012629333469582, Acc 0.6175; Test: Cost 2.013231624411891, Acc 0.65. Time 0.06626248359680176
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 12/500, Train size 1200, Test size 100......
# Training at Epoch 12/500, Batch 1, Cost 2.0092193013617425, Acc 0.6583333333333333. Time 0.062143802642822266
# Epoch 12/500, Train: Cost 2.0092193013617425, Acc 0.6583333333333333; Test: Cost 2.0106735885597002, Acc 0.65. Time 0.06654810905456543
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 13/500, Train size 1200, Test size 100......
# Training at Epoch 13/500, Batch 1, Cost 2.0059883161698875, Acc 0.6875. Time 0.062033653259277344
# Epoch 13/500, Train: Cost 2.0059883161698875, Acc 0.6875; Test: Cost 2.008851773264165, Acc 0.69. Time 0.06763768196105957
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 14/500, Train size 1200, Test size 100......
# Training at Epoch 14/500, Batch 1, Cost 2.0036787838468917, Acc 0.6866666666666666. Time 0.06208968162536621
# Epoch 14/500, Train: Cost 2.0036787838468917, Acc 0.6866666666666666; Test: Cost 2.0079477928291523, Acc 0.71. Time 0.06645774841308594
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 15/500, Train size 1200, Test size 100......
# Training at Epoch 15/500, Batch 1, Cost 2.002319930026601, Acc 0.6925. Time 0.0620572566986084
# Epoch 15/500, Train: Cost 2.002319930026601, Acc 0.6925; Test: Cost 2.007255671999727, Acc 0.69. Time 0.06636881828308105
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 16/500, Train size 1200, Test size 100......
# Training at Epoch 16/500, Batch 1, Cost 2.0011076072891534, Acc 0.695. Time 0.06207418441772461
# Epoch 16/500, Train: Cost 2.0011076072891534, Acc 0.695; Test: Cost 2.006799775684917, Acc 0.72. Time 0.06912660598754883
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 17/500, Train size 1200, Test size 100......
# Training at Epoch 17/500, Batch 1, Cost 1.9998844930462698, Acc 0.6825. Time 0.062053680419921875
# Epoch 17/500, Train: Cost 1.9998844930462698, Acc 0.6825; Test: Cost 2.006908283048248, Acc 0.68. Time 0.06643056869506836
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 18/500, Train size 1200, Test size 100......
# Training at Epoch 18/500, Batch 1, Cost 1.99893732449894, Acc 0.6583333333333333. Time 0.0620732307434082
# Epoch 18/500, Train: Cost 1.99893732449894, Acc 0.6583333333333333; Test: Cost 2.007455475807353, Acc 0.65. Time 0.06662750244140625
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 19/500, Train size 1200, Test size 100......
# Training at Epoch 19/500, Batch 1, Cost 1.9981396593258713, Acc 0.6475. Time 0.06235694885253906
# Epoch 19/500, Train: Cost 1.9981396593258713, Acc 0.6475; Test: Cost 2.007994218998362, Acc 0.63. Time 0.07543325424194336
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 20/500, Train size 1200, Test size 100......
# Training at Epoch 20/500, Batch 1, Cost 1.9971150587143205, Acc 0.6475. Time 0.06218290328979492
# Epoch 20/500, Train: Cost 1.9971150587143205, Acc 0.6475; Test: Cost 2.00792565541375, Acc 0.63. Time 0.06663370132446289
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 21/500, Train size 1200, Test size 100......
# Training at Epoch 21/500, Batch 1, Cost 1.9958419684323692, Acc 0.645. Time 0.06205558776855469
# Epoch 21/500, Train: Cost 1.9958419684323692, Acc 0.645; Test: Cost 2.0063628534600877, Acc 0.65. Time 0.06645703315734863
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 22/500, Train size 1200, Test size 100......
# Training at Epoch 22/500, Batch 1, Cost 1.9942358115874057, Acc 0.6483333333333333. Time 0.06196022033691406
# Epoch 22/500, Train: Cost 1.9942358115874057, Acc 0.6483333333333333; Test: Cost 2.0035858842228125, Acc 0.65. Time 0.06663823127746582
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 23/500, Train size 1200, Test size 100......
# Training at Epoch 23/500, Batch 1, Cost 1.9926797999775463, Acc 0.6525. Time 0.061980485916137695
# Epoch 23/500, Train: Cost 1.9926797999775463, Acc 0.6525; Test: Cost 2.00085436238341, Acc 0.67. Time 0.0663292407989502
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 24/500, Train size 1200, Test size 100......
# Training at Epoch 24/500, Batch 1, Cost 1.991495951348192, Acc 0.6391666666666667. Time 0.06218576431274414
# Epoch 24/500, Train: Cost 1.991495951348192, Acc 0.6391666666666667; Test: Cost 1.998599581693521, Acc 0.65. Time 0.0666038990020752
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 25/500, Train size 1200, Test size 100......
# Training at Epoch 25/500, Batch 1, Cost 1.9900407057041571, Acc 0.6408333333333334. Time 0.06212306022644043
# Epoch 25/500, Train: Cost 1.9900407057041571, Acc 0.6408333333333334; Test: Cost 1.9968684899326292, Acc 0.65. Time 0.06677842140197754
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 26/500, Train size 1200, Test size 100......
# Training at Epoch 26/500, Batch 1, Cost 1.9882226563362728, Acc 0.6366666666666667. Time 0.062308311462402344
# Epoch 26/500, Train: Cost 1.9882226563362728, Acc 0.6366666666666667; Test: Cost 1.995212745498734, Acc 0.64. Time 0.0685122013092041
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 27/500, Train size 1200, Test size 100......
# Training at Epoch 27/500, Batch 1, Cost 1.9862399971606368, Acc 0.62. Time 0.06205916404724121
# Epoch 27/500, Train: Cost 1.9862399971606368, Acc 0.62; Test: Cost 1.9937682430201598, Acc 0.64. Time 0.06645345687866211
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 28/500, Train size 1200, Test size 100......
# Training at Epoch 28/500, Batch 1, Cost 1.984534166051688, Acc 0.6175. Time 0.06206178665161133
# Epoch 28/500, Train: Cost 1.984534166051688, Acc 0.6175; Test: Cost 1.992571572758296, Acc 0.65. Time 0.06643056869506836
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 29/500, Train size 1200, Test size 100......
# Training at Epoch 29/500, Batch 1, Cost 1.9831235481601617, Acc 0.64. Time 0.062027692794799805
# Epoch 29/500, Train: Cost 1.9831235481601617, Acc 0.64; Test: Cost 1.990589695016045, Acc 0.68. Time 0.06642389297485352
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 30/500, Train size 1200, Test size 100......
# Training at Epoch 30/500, Batch 1, Cost 1.9812384279156157, Acc 0.6483333333333333. Time 0.06250309944152832
# Epoch 30/500, Train: Cost 1.9812384279156157, Acc 0.6483333333333333; Test: Cost 1.9875370061946127, Acc 0.68. Time 0.06833457946777344
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 31/500, Train size 1200, Test size 100......
# Training at Epoch 31/500, Batch 1, Cost 1.978958351479217, Acc 0.6575. Time 0.06219363212585449
# Epoch 31/500, Train: Cost 1.978958351479217, Acc 0.6575; Test: Cost 1.9838504628531946, Acc 0.68. Time 0.06912517547607422
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 32/500, Train size 1200, Test size 100......
# Training at Epoch 32/500, Batch 1, Cost 1.9768146871873107, Acc 0.6975. Time 0.06203174591064453
# Epoch 32/500, Train: Cost 1.9768146871873107, Acc 0.6975; Test: Cost 1.9801013037436184, Acc 0.71. Time 0.06649208068847656
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 33/500, Train size 1200, Test size 100......
# Training at Epoch 33/500, Batch 1, Cost 1.9749593692813197, Acc 0.72. Time 0.06210660934448242
# Epoch 33/500, Train: Cost 1.9749593692813197, Acc 0.72; Test: Cost 1.9772405008506893, Acc 0.76. Time 0.06657981872558594
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 34/500, Train size 1200, Test size 100......
# Training at Epoch 34/500, Batch 1, Cost 1.9735955393917253, Acc 0.7441666666666666. Time 0.0621793270111084
# Epoch 34/500, Train: Cost 1.9735955393917253, Acc 0.7441666666666666; Test: Cost 1.9757270847736599, Acc 0.78. Time 0.0666961669921875
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 35/500, Train size 1200, Test size 100......
# Training at Epoch 35/500, Batch 1, Cost 1.9727201333919782, Acc 0.7675. Time 0.062088966369628906
# Epoch 35/500, Train: Cost 1.9727201333919782, Acc 0.7675; Test: Cost 1.975285670021487, Acc 0.78. Time 0.06649112701416016
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 36/500, Train size 1200, Test size 100......
# Training at Epoch 36/500, Batch 1, Cost 1.9720290897109518, Acc 0.79. Time 0.06265497207641602
# Epoch 36/500, Train: Cost 1.9720290897109518, Acc 0.79; Test: Cost 1.9753685472885036, Acc 0.82. Time 0.06997990608215332
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 37/500, Train size 1200, Test size 100......
# Training at Epoch 37/500, Batch 1, Cost 1.9712261079846967, Acc 0.8016666666666666. Time 0.062009334564208984
# Epoch 37/500, Train: Cost 1.9712261079846967, Acc 0.8016666666666666; Test: Cost 1.9756856800546254, Acc 0.83. Time 0.0674598217010498
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 38/500, Train size 1200, Test size 100......
# Training at Epoch 38/500, Batch 1, Cost 1.9705693908119915, Acc 0.8083333333333333. Time 0.06209874153137207
# Epoch 38/500, Train: Cost 1.9705693908119915, Acc 0.8083333333333333; Test: Cost 1.975787491084621, Acc 0.78. Time 0.06660795211791992
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 39/500, Train size 1200, Test size 100......
# Training at Epoch 39/500, Batch 1, Cost 1.9700057437716771, Acc 0.8016666666666666. Time 0.062276363372802734
# Epoch 39/500, Train: Cost 1.9700057437716771, Acc 0.8016666666666666; Test: Cost 1.9754708303904196, Acc 0.79. Time 0.06743884086608887
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 40/500, Train size 1200, Test size 100......
# Training at Epoch 40/500, Batch 1, Cost 1.9693423341225698, Acc 0.7816666666666666. Time 0.06207752227783203
# Epoch 40/500, Train: Cost 1.9693423341225698, Acc 0.7816666666666666; Test: Cost 1.974938547070492, Acc 0.77. Time 0.06651067733764648
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 41/500, Train size 1200, Test size 100......
# Training at Epoch 41/500, Batch 1, Cost 1.9686660845423476, Acc 0.7775. Time 0.06223940849304199
# Epoch 41/500, Train: Cost 1.9686660845423476, Acc 0.7775; Test: Cost 1.9740931525523764, Acc 0.76. Time 0.06666350364685059
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 42/500, Train size 1200, Test size 100......
# Training at Epoch 42/500, Batch 1, Cost 1.967785143373119, Acc 0.7691666666666667. Time 0.06195259094238281
# Epoch 42/500, Train: Cost 1.967785143373119, Acc 0.7691666666666667; Test: Cost 1.9727586271439135, Acc 0.76. Time 0.0687103271484375
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 43/500, Train size 1200, Test size 100......
# Training at Epoch 43/500, Batch 1, Cost 1.966600427982835, Acc 0.7625. Time 0.06244969367980957
# Epoch 43/500, Train: Cost 1.966600427982835, Acc 0.7625; Test: Cost 1.9712381980483953, Acc 0.74. Time 0.07003569602966309
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 44/500, Train size 1200, Test size 100......
# Training at Epoch 44/500, Batch 1, Cost 1.965492714749909, Acc 0.75. Time 0.06232953071594238
# Epoch 44/500, Train: Cost 1.965492714749909, Acc 0.75; Test: Cost 1.9698433601783292, Acc 0.71. Time 0.06941699981689453
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 45/500, Train size 1200, Test size 100......
# Training at Epoch 45/500, Batch 1, Cost 1.9645867369452157, Acc 0.7383333333333333. Time 0.06239056587219238
# Epoch 45/500, Train: Cost 1.9645867369452157, Acc 0.7383333333333333; Test: Cost 1.9689170764733464, Acc 0.68. Time 0.06909561157226562
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 46/500, Train size 1200, Test size 100......
# Training at Epoch 46/500, Batch 1, Cost 1.9639730162486422, Acc 0.7116666666666667. Time 0.06220531463623047
# Epoch 46/500, Train: Cost 1.9639730162486422, Acc 0.7116666666666667; Test: Cost 1.968523058376672, Acc 0.69. Time 0.06858086585998535
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 47/500, Train size 1200, Test size 100......
# Training at Epoch 47/500, Batch 1, Cost 1.9637465308198998, Acc 0.6941666666666667. Time 0.06231117248535156
# Epoch 47/500, Train: Cost 1.9637465308198998, Acc 0.6941666666666667; Test: Cost 1.9681175398613722, Acc 0.69. Time 0.06884956359863281
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 48/500, Train size 1200, Test size 100......
# Training at Epoch 48/500, Batch 1, Cost 1.963581941456713, Acc 0.6916666666666667. Time 0.06229043006896973
# Epoch 48/500, Train: Cost 1.963581941456713, Acc 0.6916666666666667; Test: Cost 1.9674030270240201, Acc 0.68. Time 0.0689244270324707
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 49/500, Train size 1200, Test size 100......
# Training at Epoch 49/500, Batch 1, Cost 1.9632092183589658, Acc 0.6908333333333333. Time 0.062211036682128906
# Epoch 49/500, Train: Cost 1.9632092183589658, Acc 0.6908333333333333; Test: Cost 1.9664595024196438, Acc 0.67. Time 0.06839513778686523
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 50/500, Train size 1200, Test size 100......
# Training at Epoch 50/500, Batch 1, Cost 1.9625311731535469, Acc 0.695. Time 0.06228017807006836
# Epoch 50/500, Train: Cost 1.9625311731535469, Acc 0.695; Test: Cost 1.965418772376574, Acc 0.69. Time 0.06832647323608398
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 51/500, Train size 1200, Test size 100......
# Training at Epoch 51/500, Batch 1, Cost 1.9616690791536786, Acc 0.7025. Time 0.06255698204040527
# Epoch 51/500, Train: Cost 1.9616690791536786, Acc 0.7025; Test: Cost 1.9642960298508951, Acc 0.7. Time 0.06859111785888672
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 52/500, Train size 1200, Test size 100......
# Training at Epoch 52/500, Batch 1, Cost 1.9608742142782187, Acc 0.7166666666666667. Time 0.06222271919250488
# Epoch 52/500, Train: Cost 1.9608742142782187, Acc 0.7166666666666667; Test: Cost 1.9630657980663957, Acc 0.69. Time 0.06801891326904297
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 53/500, Train size 1200, Test size 100......
# Training at Epoch 53/500, Batch 1, Cost 1.9601978668401125, Acc 0.7175. Time 0.06206631660461426
# Epoch 53/500, Train: Cost 1.9601978668401125, Acc 0.7175; Test: Cost 1.9620352647996568, Acc 0.71. Time 0.06756329536437988
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 54/500, Train size 1200, Test size 100......
# Training at Epoch 54/500, Batch 1, Cost 1.9597638350667028, Acc 0.725. Time 0.06235504150390625
# Epoch 54/500, Train: Cost 1.9597638350667028, Acc 0.725; Test: Cost 1.9614719947944776, Acc 0.73. Time 0.06838679313659668
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 55/500, Train size 1200, Test size 100......
# Training at Epoch 55/500, Batch 1, Cost 1.9595549492475137, Acc 0.7308333333333333. Time 0.06307792663574219
# Epoch 55/500, Train: Cost 1.9595549492475137, Acc 0.7308333333333333; Test: Cost 1.9613811248152389, Acc 0.72. Time 0.06998205184936523
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 56/500, Train size 1200, Test size 100......
# Training at Epoch 56/500, Batch 1, Cost 1.9594077153634313, Acc 0.7333333333333333. Time 0.0623776912689209
# Epoch 56/500, Train: Cost 1.9594077153634313, Acc 0.7333333333333333; Test: Cost 1.9615294166701303, Acc 0.72. Time 0.07062220573425293
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 57/500, Train size 1200, Test size 100......
# Training at Epoch 57/500, Batch 1, Cost 1.9592662833489303, Acc 0.7241666666666666. Time 0.06213498115539551
# Epoch 57/500, Train: Cost 1.9592662833489303, Acc 0.7241666666666666; Test: Cost 1.9615332062599466, Acc 0.7. Time 0.0688478946685791
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 58/500, Train size 1200, Test size 100......
# Training at Epoch 58/500, Batch 1, Cost 1.9590380701379886, Acc 0.7125. Time 0.06205034255981445
# Epoch 58/500, Train: Cost 1.9590380701379886, Acc 0.7125; Test: Cost 1.9613638146482675, Acc 0.7. Time 0.06874680519104004
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 59/500, Train size 1200, Test size 100......
# Training at Epoch 59/500, Batch 1, Cost 1.9588078641545585, Acc 0.7033333333333334. Time 0.06240582466125488
# Epoch 59/500, Train: Cost 1.9588078641545585, Acc 0.7033333333333334; Test: Cost 1.9610948308400844, Acc 0.69. Time 0.0725395679473877
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 60/500, Train size 1200, Test size 100......
# Training at Epoch 60/500, Batch 1, Cost 1.958605586095071, Acc 0.695. Time 0.0623011589050293
# Epoch 60/500, Train: Cost 1.958605586095071, Acc 0.695; Test: Cost 1.96076347091429, Acc 0.67. Time 0.06974983215332031
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 61/500, Train size 1200, Test size 100......
# Training at Epoch 61/500, Batch 1, Cost 1.9584320989012054, Acc 0.6891666666666667. Time 0.0626375675201416
# Epoch 61/500, Train: Cost 1.9584320989012054, Acc 0.6891666666666667; Test: Cost 1.960341339028991, Acc 0.66. Time 0.06950116157531738
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 62/500, Train size 1200, Test size 100......
# Training at Epoch 62/500, Batch 1, Cost 1.958216501019828, Acc 0.6891666666666667. Time 0.062476158142089844
# Epoch 62/500, Train: Cost 1.958216501019828, Acc 0.6891666666666667; Test: Cost 1.9598966955431898, Acc 0.66. Time 0.07073760032653809
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 63/500, Train size 1200, Test size 100......
# Training at Epoch 63/500, Batch 1, Cost 1.95791981360932, Acc 0.7033333333333334. Time 0.06211352348327637
# Epoch 63/500, Train: Cost 1.95791981360932, Acc 0.7033333333333334; Test: Cost 1.959671526099885, Acc 0.66. Time 0.06871628761291504
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 64/500, Train size 1200, Test size 100......
# Training at Epoch 64/500, Batch 1, Cost 1.9575938993257957, Acc 0.7125. Time 0.06220865249633789
# Epoch 64/500, Train: Cost 1.9575938993257957, Acc 0.7125; Test: Cost 1.9597242344647061, Acc 0.68. Time 0.07053923606872559
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 65/500, Train size 1200, Test size 100......
# Training at Epoch 65/500, Batch 1, Cost 1.9572769208354959, Acc 0.7258333333333333. Time 0.06226682662963867
# Epoch 65/500, Train: Cost 1.9572769208354959, Acc 0.7258333333333333; Test: Cost 1.959828553552298, Acc 0.7. Time 0.06889939308166504
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 66/500, Train size 1200, Test size 100......
# Training at Epoch 66/500, Batch 1, Cost 1.9570604693936413, Acc 0.7333333333333333. Time 0.062133073806762695
# Epoch 66/500, Train: Cost 1.9570604693936413, Acc 0.7333333333333333; Test: Cost 1.959669723230215, Acc 0.7. Time 0.0686502456665039
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 67/500, Train size 1200, Test size 100......
# Training at Epoch 67/500, Batch 1, Cost 1.9569354434311224, Acc 0.7425. Time 0.0621645450592041
# Epoch 67/500, Train: Cost 1.9569354434311224, Acc 0.7425; Test: Cost 1.9591772099168234, Acc 0.73. Time 0.06926703453063965
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 68/500, Train size 1200, Test size 100......
# Training at Epoch 68/500, Batch 1, Cost 1.9568024572619478, Acc 0.7508333333333334. Time 0.06230354309082031
# Epoch 68/500, Train: Cost 1.9568024572619478, Acc 0.7508333333333334; Test: Cost 1.9585898813115075, Acc 0.74. Time 0.06790733337402344
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 69/500, Train size 1200, Test size 100......
# Training at Epoch 69/500, Batch 1, Cost 1.9566257322082692, Acc 0.75. Time 0.062124013900756836
# Epoch 69/500, Train: Cost 1.9566257322082692, Acc 0.75; Test: Cost 1.9581515256894393, Acc 0.75. Time 0.06704163551330566
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 70/500, Train size 1200, Test size 100......
# Training at Epoch 70/500, Batch 1, Cost 1.9564523586317555, Acc 0.7491666666666666. Time 0.06208539009094238
# Epoch 70/500, Train: Cost 1.9564523586317555, Acc 0.7491666666666666; Test: Cost 1.9578321735418078, Acc 0.74. Time 0.0667428970336914
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 71/500, Train size 1200, Test size 100......
# Training at Epoch 71/500, Batch 1, Cost 1.9563043267933162, Acc 0.7533333333333333. Time 0.061968326568603516
# Epoch 71/500, Train: Cost 1.9563043267933162, Acc 0.7533333333333333; Test: Cost 1.9575273242740598, Acc 0.75. Time 0.06683707237243652
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 72/500, Train size 1200, Test size 100......
# Training at Epoch 72/500, Batch 1, Cost 1.956166104166551, Acc 0.7525. Time 0.06196427345275879
# Epoch 72/500, Train: Cost 1.956166104166551, Acc 0.7525; Test: Cost 1.957308661073547, Acc 0.75. Time 0.068572998046875
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 73/500, Train size 1200, Test size 100......
# Training at Epoch 73/500, Batch 1, Cost 1.9560356217635668, Acc 0.7508333333333334. Time 0.061942100524902344
# Epoch 73/500, Train: Cost 1.9560356217635668, Acc 0.7508333333333334; Test: Cost 1.957150723791446, Acc 0.73. Time 0.06626510620117188
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 74/500, Train size 1200, Test size 100......
# Training at Epoch 74/500, Batch 1, Cost 1.9558914297382013, Acc 0.7441666666666666. Time 0.0618138313293457
# Epoch 74/500, Train: Cost 1.9558914297382013, Acc 0.7441666666666666; Test: Cost 1.9568873563629898, Acc 0.73. Time 0.06715226173400879
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 75/500, Train size 1200, Test size 100......
# Training at Epoch 75/500, Batch 1, Cost 1.9557487698510907, Acc 0.7433333333333333. Time 0.06184792518615723
# Epoch 75/500, Train: Cost 1.9557487698510907, Acc 0.7433333333333333; Test: Cost 1.956492797958739, Acc 0.72. Time 0.06633329391479492
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 76/500, Train size 1200, Test size 100......
# Training at Epoch 76/500, Batch 1, Cost 1.9556230747809826, Acc 0.745. Time 0.06215071678161621
# Epoch 76/500, Train: Cost 1.9556230747809826, Acc 0.745; Test: Cost 1.956089878542249, Acc 0.72. Time 0.06664705276489258
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 77/500, Train size 1200, Test size 100......
# Training at Epoch 77/500, Batch 1, Cost 1.9555043838257224, Acc 0.7408333333333333. Time 0.06236672401428223
# Epoch 77/500, Train: Cost 1.9555043838257224, Acc 0.7408333333333333; Test: Cost 1.955708156653213, Acc 0.72. Time 0.0679008960723877
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 78/500, Train size 1200, Test size 100......
# Training at Epoch 78/500, Batch 1, Cost 1.955389557201346, Acc 0.7391666666666666. Time 0.06248307228088379
# Epoch 78/500, Train: Cost 1.955389557201346, Acc 0.7391666666666666; Test: Cost 1.955283815977764, Acc 0.72. Time 0.06693029403686523
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 79/500, Train size 1200, Test size 100......
# Training at Epoch 79/500, Batch 1, Cost 1.955294220237277, Acc 0.74. Time 0.06202888488769531
# Epoch 79/500, Train: Cost 1.955294220237277, Acc 0.74; Test: Cost 1.9547962287577276, Acc 0.73. Time 0.06795978546142578
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 80/500, Train size 1200, Test size 100......
# Training at Epoch 80/500, Batch 1, Cost 1.9551987206490258, Acc 0.7341666666666666. Time 0.06291007995605469
# Epoch 80/500, Train: Cost 1.9551987206490258, Acc 0.7341666666666666; Test: Cost 1.9543200234951468, Acc 0.73. Time 0.06804752349853516
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 81/500, Train size 1200, Test size 100......
# Training at Epoch 81/500, Batch 1, Cost 1.9550962893080965, Acc 0.7291666666666666. Time 0.06196165084838867
# Epoch 81/500, Train: Cost 1.9550962893080965, Acc 0.7291666666666666; Test: Cost 1.9538752922570417, Acc 0.73. Time 0.06632256507873535
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 82/500, Train size 1200, Test size 100......
# Training at Epoch 82/500, Batch 1, Cost 1.9549950388670838, Acc 0.7275. Time 0.06194353103637695
# Epoch 82/500, Train: Cost 1.9549950388670838, Acc 0.7275; Test: Cost 1.9533979649025883, Acc 0.73. Time 0.06671929359436035
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 83/500, Train size 1200, Test size 100......
# Training at Epoch 83/500, Batch 1, Cost 1.9548938105575464, Acc 0.7316666666666667. Time 0.061988115310668945
# Epoch 83/500, Train: Cost 1.9548938105575464, Acc 0.7316666666666667; Test: Cost 1.952903303151112, Acc 0.74. Time 0.06661343574523926
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 84/500, Train size 1200, Test size 100......
# Training at Epoch 84/500, Batch 1, Cost 1.9547984032531858, Acc 0.735. Time 0.06208515167236328
# Epoch 84/500, Train: Cost 1.9547984032531858, Acc 0.735; Test: Cost 1.9524983942591092, Acc 0.73. Time 0.0664973258972168
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 85/500, Train size 1200, Test size 100......
# Training at Epoch 85/500, Batch 1, Cost 1.9547197184855563, Acc 0.7391666666666666. Time 0.06202101707458496
# Epoch 85/500, Train: Cost 1.9547197184855563, Acc 0.7391666666666666; Test: Cost 1.952182389878592, Acc 0.74. Time 0.06898665428161621
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 86/500, Train size 1200, Test size 100......
# Training at Epoch 86/500, Batch 1, Cost 1.9546466477526396, Acc 0.7425. Time 0.06204819679260254
# Epoch 86/500, Train: Cost 1.9546466477526396, Acc 0.7425; Test: Cost 1.9518521647789415, Acc 0.75. Time 0.0666050910949707
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 87/500, Train size 1200, Test size 100......
# Training at Epoch 87/500, Batch 1, Cost 1.9545698963266294, Acc 0.745. Time 0.062116146087646484
# Epoch 87/500, Train: Cost 1.9545698963266294, Acc 0.745; Test: Cost 1.9514657020391513, Acc 0.77. Time 0.06781530380249023
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 88/500, Train size 1200, Test size 100......
# Training at Epoch 88/500, Batch 1, Cost 1.954478798821058, Acc 0.755. Time 0.06223630905151367
# Epoch 88/500, Train: Cost 1.954478798821058, Acc 0.755; Test: Cost 1.9510794780665524, Acc 0.78. Time 0.0690770149230957
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 89/500, Train size 1200, Test size 100......
# Training at Epoch 89/500, Batch 1, Cost 1.9543827300244259, Acc 0.7658333333333334. Time 0.06210470199584961
# Epoch 89/500, Train: Cost 1.9543827300244259, Acc 0.7658333333333334; Test: Cost 1.9507432414053076, Acc 0.81. Time 0.06683564186096191
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 90/500, Train size 1200, Test size 100......
# Training at Epoch 90/500, Batch 1, Cost 1.9543054658632026, Acc 0.7716666666666666. Time 0.06238150596618652
# Epoch 90/500, Train: Cost 1.9543054658632026, Acc 0.7716666666666666; Test: Cost 1.9504510833997761, Acc 0.82. Time 0.06688165664672852
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 91/500, Train size 1200, Test size 100......
# Training at Epoch 91/500, Batch 1, Cost 1.9542393670816494, Acc 0.7766666666666666. Time 0.061966896057128906
# Epoch 91/500, Train: Cost 1.9542393670816494, Acc 0.7766666666666666; Test: Cost 1.9502101538463437, Acc 0.83. Time 0.06720447540283203
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 92/500, Train size 1200, Test size 100......
# Training at Epoch 92/500, Batch 1, Cost 1.9541703746221593, Acc 0.7775. Time 0.06276822090148926
# Epoch 92/500, Train: Cost 1.9541703746221593, Acc 0.7775; Test: Cost 1.9500258300033, Acc 0.83. Time 0.0673670768737793
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 93/500, Train size 1200, Test size 100......
# Training at Epoch 93/500, Batch 1, Cost 1.9540980005932542, Acc 0.7783333333333333. Time 0.06182432174682617
# Epoch 93/500, Train: Cost 1.9540980005932542, Acc 0.7783333333333333; Test: Cost 1.9498591774012612, Acc 0.83. Time 0.0663142204284668
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 94/500, Train size 1200, Test size 100......
# Training at Epoch 94/500, Batch 1, Cost 1.9540245457621717, Acc 0.7791666666666667. Time 0.06408286094665527
# Epoch 94/500, Train: Cost 1.9540245457621717, Acc 0.7791666666666667; Test: Cost 1.9497006378974369, Acc 0.83. Time 0.07488679885864258
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 95/500, Train size 1200, Test size 100......
# Training at Epoch 95/500, Batch 1, Cost 1.9539565678873174, Acc 0.7858333333333334. Time 0.06196737289428711
# Epoch 95/500, Train: Cost 1.9539565678873174, Acc 0.7858333333333334; Test: Cost 1.9495711812921814, Acc 0.84. Time 0.06667280197143555
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 96/500, Train size 1200, Test size 100......
# Training at Epoch 96/500, Batch 1, Cost 1.9538901153979966, Acc 0.7883333333333333. Time 0.062033653259277344
# Epoch 96/500, Train: Cost 1.9538901153979966, Acc 0.7883333333333333; Test: Cost 1.9494454719470968, Acc 0.86. Time 0.06646370887756348
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 97/500, Train size 1200, Test size 100......
# Training at Epoch 97/500, Batch 1, Cost 1.9538192910349343, Acc 0.7975. Time 0.062033891677856445
# Epoch 97/500, Train: Cost 1.9538192910349343, Acc 0.7975; Test: Cost 1.9492701275457103, Acc 0.85. Time 0.0693507194519043
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 98/500, Train size 1200, Test size 100......
# Training at Epoch 98/500, Batch 1, Cost 1.9537434125259026, Acc 0.8033333333333333. Time 0.061992645263671875
# Epoch 98/500, Train: Cost 1.9537434125259026, Acc 0.8033333333333333; Test: Cost 1.949045808023539, Acc 0.85. Time 0.06630992889404297
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 99/500, Train size 1200, Test size 100......
# Training at Epoch 99/500, Batch 1, Cost 1.9536639736115793, Acc 0.815. Time 0.06186223030090332
# Epoch 99/500, Train: Cost 1.9536639736115793, Acc 0.815; Test: Cost 1.9488251729147397, Acc 0.86. Time 0.06628131866455078
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 100/500, Train size 1200, Test size 100......
# Training at Epoch 100/500, Batch 1, Cost 1.9535852678001857, Acc 0.8208333333333333. Time 0.06199908256530762
# Epoch 100/500, Train: Cost 1.9535852678001857, Acc 0.8208333333333333; Test: Cost 1.9486436846560753, Acc 0.86. Time 0.06638717651367188
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 101/500, Train size 1200, Test size 100......
# Training at Epoch 101/500, Batch 1, Cost 1.9535071192141074, Acc 0.825. Time 0.0620269775390625
# Epoch 101/500, Train: Cost 1.9535071192141074, Acc 0.825; Test: Cost 1.9485073546307559, Acc 0.86. Time 0.06798863410949707
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 102/500, Train size 1200, Test size 100......
# Training at Epoch 102/500, Batch 1, Cost 1.9534288332635243, Acc 0.8283333333333334. Time 0.06198692321777344
# Epoch 102/500, Train: Cost 1.9534288332635243, Acc 0.8283333333333334; Test: Cost 1.948384476489967, Acc 0.88. Time 0.06637835502624512
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 103/500, Train size 1200, Test size 100......
# Training at Epoch 103/500, Batch 1, Cost 1.9533497551746117, Acc 0.8291666666666667. Time 0.06194591522216797
# Epoch 103/500, Train: Cost 1.9533497551746117, Acc 0.8291666666666667; Test: Cost 1.9482424237792193, Acc 0.88. Time 0.06761360168457031
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 104/500, Train size 1200, Test size 100......
# Training at Epoch 104/500, Batch 1, Cost 1.9532692123105306, Acc 0.8308333333333333. Time 0.06190848350524902
# Epoch 104/500, Train: Cost 1.9532692123105306, Acc 0.8308333333333333; Test: Cost 1.948091959710439, Acc 0.88. Time 0.06940603256225586
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 105/500, Train size 1200, Test size 100......
# Training at Epoch 105/500, Batch 1, Cost 1.9531883691408114, Acc 0.8325. Time 0.06187748908996582
# Epoch 105/500, Train: Cost 1.9531883691408114, Acc 0.8325; Test: Cost 1.9479524809940956, Acc 0.88. Time 0.06627273559570312
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 106/500, Train size 1200, Test size 100......
# Training at Epoch 106/500, Batch 1, Cost 1.953107261663793, Acc 0.8333333333333334. Time 0.06192779541015625
# Epoch 106/500, Train: Cost 1.953107261663793, Acc 0.8333333333333334; Test: Cost 1.9478016039997608, Acc 0.88. Time 0.06633281707763672
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 107/500, Train size 1200, Test size 100......
# Training at Epoch 107/500, Batch 1, Cost 1.9530263685553906, Acc 0.8366666666666667. Time 0.06190609931945801
# Epoch 107/500, Train: Cost 1.9530263685553906, Acc 0.8366666666666667; Test: Cost 1.9476131286723517, Acc 0.88. Time 0.06867623329162598
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 108/500, Train size 1200, Test size 100......
# Training at Epoch 108/500, Batch 1, Cost 1.952946925507463, Acc 0.8391666666666666. Time 0.06196308135986328
# Epoch 108/500, Train: Cost 1.952946925507463, Acc 0.8391666666666666; Test: Cost 1.9473994103142955, Acc 0.88. Time 0.0665900707244873
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 109/500, Train size 1200, Test size 100......
# Training at Epoch 109/500, Batch 1, Cost 1.9528699232340114, Acc 0.84. Time 0.06168866157531738
# Epoch 109/500, Train: Cost 1.9528699232340114, Acc 0.84; Test: Cost 1.947171333348245, Acc 0.89. Time 0.06879448890686035
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 110/500, Train size 1200, Test size 100......
# Training at Epoch 110/500, Batch 1, Cost 1.9527950014865847, Acc 0.8416666666666667. Time 0.06187939643859863
# Epoch 110/500, Train: Cost 1.9527950014865847, Acc 0.8416666666666667; Test: Cost 1.9469368510857918, Acc 0.88. Time 0.06634640693664551
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 111/500, Train size 1200, Test size 100......
# Training at Epoch 111/500, Batch 1, Cost 1.9527206326616047, Acc 0.8458333333333333. Time 0.06197690963745117
# Epoch 111/500, Train: Cost 1.9527206326616047, Acc 0.8458333333333333; Test: Cost 1.9467184486628126, Acc 0.89. Time 0.0668494701385498
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 112/500, Train size 1200, Test size 100......
# Training at Epoch 112/500, Batch 1, Cost 1.9526489664138948, Acc 0.8475. Time 0.06196093559265137
# Epoch 112/500, Train: Cost 1.9526489664138948, Acc 0.8475; Test: Cost 1.9465279829475202, Acc 0.88. Time 0.06731724739074707
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 113/500, Train size 1200, Test size 100......
# Training at Epoch 113/500, Batch 1, Cost 1.9525796811682719, Acc 0.8458333333333333. Time 0.06201028823852539
# Epoch 113/500, Train: Cost 1.9525796811682719, Acc 0.8458333333333333; Test: Cost 1.9463585568977124, Acc 0.88. Time 0.06697607040405273
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 114/500, Train size 1200, Test size 100......
# Training at Epoch 114/500, Batch 1, Cost 1.9525115519435243, Acc 0.8458333333333333. Time 0.06187629699707031
# Epoch 114/500, Train: Cost 1.9525115519435243, Acc 0.8458333333333333; Test: Cost 1.946230859011032, Acc 0.88. Time 0.06632566452026367
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 115/500, Train size 1200, Test size 100......
# Training at Epoch 115/500, Batch 1, Cost 1.952444228603334, Acc 0.8475. Time 0.06192135810852051
# Epoch 115/500, Train: Cost 1.952444228603334, Acc 0.8475; Test: Cost 1.9461384833017812, Acc 0.89. Time 0.06631970405578613
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 116/500, Train size 1200, Test size 100......
# Training at Epoch 116/500, Batch 1, Cost 1.952377216056967, Acc 0.8525. Time 0.06192350387573242
# Epoch 116/500, Train: Cost 1.952377216056967, Acc 0.8525; Test: Cost 1.9460587439210093, Acc 0.89. Time 0.0662083625793457
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 117/500, Train size 1200, Test size 100......
# Training at Epoch 117/500, Batch 1, Cost 1.9523110109905046, Acc 0.8508333333333333. Time 0.06291794776916504
# Epoch 117/500, Train: Cost 1.9523110109905046, Acc 0.8508333333333333; Test: Cost 1.9459726444996648, Acc 0.89. Time 0.06806683540344238
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 118/500, Train size 1200, Test size 100......
# Training at Epoch 118/500, Batch 1, Cost 1.9522451671687229, Acc 0.8541666666666666. Time 0.0621495246887207
# Epoch 118/500, Train: Cost 1.9522451671687229, Acc 0.8541666666666666; Test: Cost 1.9459232307449486, Acc 0.89. Time 0.0665130615234375
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 119/500, Train size 1200, Test size 100......
# Training at Epoch 119/500, Batch 1, Cost 1.952180873024118, Acc 0.8508333333333333. Time 0.061876535415649414
# Epoch 119/500, Train: Cost 1.952180873024118, Acc 0.8508333333333333; Test: Cost 1.9458826924433776, Acc 0.89. Time 0.06622695922851562
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 120/500, Train size 1200, Test size 100......
# Training at Epoch 120/500, Batch 1, Cost 1.9521227060432482, Acc 0.8575. Time 0.061953067779541016
# Epoch 120/500, Train: Cost 1.9521227060432482, Acc 0.8575; Test: Cost 1.9459187540780036, Acc 0.89. Time 0.06638979911804199
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 121/500, Train size 1200, Test size 100......
# Training at Epoch 121/500, Batch 1, Cost 1.9520879116751106, Acc 0.8466666666666667. Time 0.06185102462768555
# Epoch 121/500, Train: Cost 1.9520879116751106, Acc 0.8466666666666667; Test: Cost 1.9459616332602423, Acc 0.88. Time 0.06621217727661133
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 122/500, Train size 1200, Test size 100......
# Training at Epoch 122/500, Batch 1, Cost 1.9521204005471244, Acc 0.8641666666666666. Time 0.06200432777404785
# Epoch 122/500, Train: Cost 1.9521204005471244, Acc 0.8641666666666666; Test: Cost 1.9463437175431477, Acc 0.9. Time 0.06641507148742676
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 123/500, Train size 1200, Test size 100......
# Training at Epoch 123/500, Batch 1, Cost 1.9523441683629805, Acc 0.8275. Time 0.06185746192932129
# Epoch 123/500, Train: Cost 1.9523441683629805, Acc 0.8275; Test: Cost 1.946830618237634, Acc 0.88. Time 0.06862568855285645
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 124/500, Train size 1200, Test size 100......
# Training at Epoch 124/500, Batch 1, Cost 1.9529013028683317, Acc 0.8633333333333333. Time 0.06188821792602539
# Epoch 124/500, Train: Cost 1.9529013028683317, Acc 0.8633333333333333; Test: Cost 1.9478462092586863, Acc 0.89. Time 0.06759953498840332
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 125/500, Train size 1200, Test size 100......
# Training at Epoch 125/500, Batch 1, Cost 1.9535093054578814, Acc 0.8283333333333334. Time 0.06226468086242676
# Epoch 125/500, Train: Cost 1.9535093054578814, Acc 0.8283333333333334; Test: Cost 1.9469807372040344, Acc 0.88. Time 0.06668996810913086
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 126/500, Train size 1200, Test size 100......
# Training at Epoch 126/500, Batch 1, Cost 1.9529075356460006, Acc 0.8575. Time 0.06193232536315918
# Epoch 126/500, Train: Cost 1.9529075356460006, Acc 0.8575; Test: Cost 1.9461736876216789, Acc 0.9. Time 0.06696367263793945
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 127/500, Train size 1200, Test size 100......
# Training at Epoch 127/500, Batch 1, Cost 1.9516867172651307, Acc 0.8608333333333333. Time 0.06180238723754883
# Epoch 127/500, Train: Cost 1.9516867172651307, Acc 0.8608333333333333; Test: Cost 1.9464664546191308, Acc 0.9. Time 0.0669853687286377
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 128/500, Train size 1200, Test size 100......
# Training at Epoch 128/500, Batch 1, Cost 1.9518370649177808, Acc 0.8308333333333333. Time 0.06193661689758301
# Epoch 128/500, Train: Cost 1.9518370649177808, Acc 0.8308333333333333; Test: Cost 1.9468583824924253, Acc 0.88. Time 0.06634068489074707
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 129/500, Train size 1200, Test size 100......
# Training at Epoch 129/500, Batch 1, Cost 1.9524860659342549, Acc 0.8625. Time 0.062026262283325195
# Epoch 129/500, Train: Cost 1.9524860659342549, Acc 0.8625; Test: Cost 1.9466794195673995, Acc 0.9. Time 0.06719207763671875
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 130/500, Train size 1200, Test size 100......
# Training at Epoch 130/500, Batch 1, Cost 1.951842918553652, Acc 0.8541666666666666. Time 0.061914920806884766
# Epoch 130/500, Train: Cost 1.951842918553652, Acc 0.8541666666666666; Test: Cost 1.945952927257431, Acc 0.91. Time 0.06676793098449707
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 131/500, Train size 1200, Test size 100......
# Training at Epoch 131/500, Batch 1, Cost 1.9512618964131212, Acc 0.8366666666666667. Time 0.06204700469970703
# Epoch 131/500, Train: Cost 1.9512618964131212, Acc 0.8366666666666667; Test: Cost 1.946295827451632, Acc 0.9. Time 0.06650328636169434
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 132/500, Train size 1200, Test size 100......
# Training at Epoch 132/500, Batch 1, Cost 1.9517591158540488, Acc 0.8608333333333333. Time 0.06198406219482422
# Epoch 132/500, Train: Cost 1.9517591158540488, Acc 0.8608333333333333; Test: Cost 1.9466840931277483, Acc 0.91. Time 0.06639218330383301
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 133/500, Train size 1200, Test size 100......
# Training at Epoch 133/500, Batch 1, Cost 1.9516744983286114, Acc 0.85. Time 0.06171083450317383
# Epoch 133/500, Train: Cost 1.9516744983286114, Acc 0.85; Test: Cost 1.9458454886068604, Acc 0.91. Time 0.06609272956848145
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 134/500, Train size 1200, Test size 100......
# Training at Epoch 134/500, Batch 1, Cost 1.95103152284162, Acc 0.8458333333333333. Time 0.061859130859375
# Epoch 134/500, Train: Cost 1.95103152284162, Acc 0.8458333333333333; Test: Cost 1.946002932961614, Acc 0.91. Time 0.0662240982055664
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 135/500, Train size 1200, Test size 100......
# Training at Epoch 135/500, Batch 1, Cost 1.9512378451143033, Acc 0.8633333333333333. Time 0.06196117401123047
# Epoch 135/500, Train: Cost 1.9512378451143033, Acc 0.8633333333333333; Test: Cost 1.9465280486086125, Acc 0.91. Time 0.06657576560974121
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 136/500, Train size 1200, Test size 100......
# Training at Epoch 136/500, Batch 1, Cost 1.9513733377219171, Acc 0.8516666666666667. Time 0.061803579330444336
# Epoch 136/500, Train: Cost 1.9513733377219171, Acc 0.8516666666666667; Test: Cost 1.9458477567036552, Acc 0.91. Time 0.06827831268310547
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 137/500, Train size 1200, Test size 100......
# Training at Epoch 137/500, Batch 1, Cost 1.9508765345752759, Acc 0.8525. Time 0.06192922592163086
# Epoch 137/500, Train: Cost 1.9508765345752759, Acc 0.8525; Test: Cost 1.9458986924651365, Acc 0.91. Time 0.06667494773864746
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 138/500, Train size 1200, Test size 100......
# Training at Epoch 138/500, Batch 1, Cost 1.95089767717263, Acc 0.865. Time 0.06205630302429199
# Epoch 138/500, Train: Cost 1.95089767717263, Acc 0.865; Test: Cost 1.9464001614782411, Acc 0.91. Time 0.06640005111694336
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 139/500, Train size 1200, Test size 100......
# Training at Epoch 139/500, Batch 1, Cost 1.951083638760063, Acc 0.855. Time 0.06196403503417969
# Epoch 139/500, Train: Cost 1.951083638760063, Acc 0.855; Test: Cost 1.9458844984747825, Acc 0.91. Time 0.0663444995880127
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 140/500, Train size 1200, Test size 100......
# Training at Epoch 140/500, Batch 1, Cost 1.950739830113987, Acc 0.8583333333333333. Time 0.0619962215423584
# Epoch 140/500, Train: Cost 1.950739830113987, Acc 0.8583333333333333; Test: Cost 1.945864272831662, Acc 0.91. Time 0.06639313697814941
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 141/500, Train size 1200, Test size 100......
# Training at Epoch 141/500, Batch 1, Cost 1.9506744195722385, Acc 0.865. Time 0.06178689002990723
# Epoch 141/500, Train: Cost 1.9506744195722385, Acc 0.865; Test: Cost 1.94630179222123, Acc 0.92. Time 0.06614255905151367
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 142/500, Train size 1200, Test size 100......
# Training at Epoch 142/500, Batch 1, Cost 1.950845234456291, Acc 0.8525. Time 0.06176924705505371
# Epoch 142/500, Train: Cost 1.950845234456291, Acc 0.8525; Test: Cost 1.9460072287742174, Acc 0.9. Time 0.06652569770812988
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 143/500, Train size 1200, Test size 100......
# Training at Epoch 143/500, Batch 1, Cost 1.950622556572508, Acc 0.855. Time 0.06186795234680176
# Epoch 143/500, Train: Cost 1.950622556572508, Acc 0.855; Test: Cost 1.946019219071472, Acc 0.91. Time 0.06628870964050293
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 144/500, Train size 1200, Test size 100......
# Training at Epoch 144/500, Batch 1, Cost 1.9505199810283127, Acc 0.8666666666666667. Time 0.0619046688079834
# Epoch 144/500, Train: Cost 1.9505199810283127, Acc 0.8666666666666667; Test: Cost 1.946353283700949, Acc 0.91. Time 0.06628966331481934
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 145/500, Train size 1200, Test size 100......
# Training at Epoch 145/500, Batch 1, Cost 1.9506539981128894, Acc 0.8541666666666666. Time 0.06170487403869629
# Epoch 145/500, Train: Cost 1.9506539981128894, Acc 0.8541666666666666; Test: Cost 1.9461358221196343, Acc 0.9. Time 0.06608748435974121
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 146/500, Train size 1200, Test size 100......
# Training at Epoch 146/500, Batch 1, Cost 1.950517550418138, Acc 0.8583333333333333. Time 0.06219625473022461
# Epoch 146/500, Train: Cost 1.950517550418138, Acc 0.8583333333333333; Test: Cost 1.9461320454704139, Acc 0.9. Time 0.06932353973388672
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 147/500, Train size 1200, Test size 100......
# ...
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 453/500, Train size 1200, Test size 100......
# Training at Epoch 453/500, Batch 1, Cost 1.946883822670299, Acc 0.8158333333333333. Time 0.062014102935791016
# Epoch 453/500, Train: Cost 1.946883822670299, Acc 0.8158333333333333; Test: Cost 1.937826454378299, Acc 0.84. Time 0.06856369972229004
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 454/500, Train size 1200, Test size 100......
# Training at Epoch 454/500, Batch 1, Cost 1.9469179668334802, Acc 0.8091666666666667. Time 0.06197214126586914
# Epoch 454/500, Train: Cost 1.9469179668334802, Acc 0.8091666666666667; Test: Cost 1.9373579722343826, Acc 0.83. Time 0.06943464279174805
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 455/500, Train size 1200, Test size 100......
# Training at Epoch 455/500, Batch 1, Cost 1.9469543109553147, Acc 0.8158333333333333. Time 0.06218314170837402
# Epoch 455/500, Train: Cost 1.9469543109553147, Acc 0.8158333333333333; Test: Cost 1.9380131016502236, Acc 0.84. Time 0.06902527809143066
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 456/500, Train size 1200, Test size 100......
# Training at Epoch 456/500, Batch 1, Cost 1.9469692967307213, Acc 0.8091666666666667. Time 0.06236910820007324
# Epoch 456/500, Train: Cost 1.9469692967307213, Acc 0.8091666666666667; Test: Cost 1.9373336854534302, Acc 0.83. Time 0.0690920352935791
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 457/500, Train size 1200, Test size 100......
# Training at Epoch 457/500, Batch 1, Cost 1.946956805215139, Acc 0.8175. Time 0.06220126152038574
# Epoch 457/500, Train: Cost 1.946956805215139, Acc 0.8175; Test: Cost 1.9379054894812617, Acc 0.84. Time 0.06869935989379883
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 458/500, Train size 1200, Test size 100......
# Training at Epoch 458/500, Batch 1, Cost 1.9469245172088578, Acc 0.8108333333333333. Time 0.06194710731506348
# Epoch 458/500, Train: Cost 1.9469245172088578, Acc 0.8108333333333333; Test: Cost 1.9374024536493017, Acc 0.84. Time 0.06646370887756348
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 459/500, Train size 1200, Test size 100......
# Training at Epoch 459/500, Batch 1, Cost 1.9468911522848604, Acc 0.8133333333333334. Time 0.061936378479003906
# Epoch 459/500, Train: Cost 1.9468911522848604, Acc 0.8133333333333334; Test: Cost 1.9376555021622444, Acc 0.84. Time 0.06638097763061523
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 460/500, Train size 1200, Test size 100......
# Training at Epoch 460/500, Batch 1, Cost 1.9468708743437348, Acc 0.815. Time 0.06224346160888672
# Epoch 460/500, Train: Cost 1.9468708743437348, Acc 0.815; Test: Cost 1.9375760348906814, Acc 0.84. Time 0.06907153129577637
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 461/500, Train size 1200, Test size 100......
# Training at Epoch 461/500, Batch 1, Cost 1.946868995160334, Acc 0.8125. Time 0.06186842918395996
# Epoch 461/500, Train: Cost 1.946868995160334, Acc 0.8125; Test: Cost 1.9374661239092228, Acc 0.84. Time 0.06688261032104492
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 462/500, Train size 1200, Test size 100......
# Training at Epoch 462/500, Batch 1, Cost 1.9468806833424004, Acc 0.815. Time 0.06186676025390625
# Epoch 462/500, Train: Cost 1.9468806833424004, Acc 0.815; Test: Cost 1.9377621393789541, Acc 0.84. Time 0.06631255149841309
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 463/500, Train size 1200, Test size 100......
# Training at Epoch 463/500, Batch 1, Cost 1.9468960875619918, Acc 0.8108333333333333. Time 0.06181979179382324
# Epoch 463/500, Train: Cost 1.9468960875619918, Acc 0.8108333333333333; Test: Cost 1.937396189411084, Acc 0.83. Time 0.06887078285217285
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 464/500, Train size 1200, Test size 100......
# Training at Epoch 464/500, Batch 1, Cost 1.9469063735171472, Acc 0.8158333333333333. Time 0.061937808990478516
# Epoch 464/500, Train: Cost 1.9469063735171472, Acc 0.8158333333333333; Test: Cost 1.9378272276828767, Acc 0.84. Time 0.06664443016052246
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 465/500, Train size 1200, Test size 100......
# Training at Epoch 465/500, Batch 1, Cost 1.946906202023074, Acc 0.8116666666666666. Time 0.06213021278381348
# Epoch 465/500, Train: Cost 1.946906202023074, Acc 0.8116666666666666; Test: Cost 1.9374101656815013, Acc 0.84. Time 0.0665886402130127
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 466/500, Train size 1200, Test size 100......
# Training at Epoch 466/500, Batch 1, Cost 1.9468966608636604, Acc 0.815. Time 0.06190347671508789
# Epoch 466/500, Train: Cost 1.9468966608636604, Acc 0.815; Test: Cost 1.9377495192764331, Acc 0.84. Time 0.06953024864196777
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 467/500, Train size 1200, Test size 100......
# Training at Epoch 467/500, Batch 1, Cost 1.9468813847014383, Acc 0.8125. Time 0.062027692794799805
# Epoch 467/500, Train: Cost 1.9468813847014383, Acc 0.8125; Test: Cost 1.937470447923846, Acc 0.84. Time 0.06692886352539062
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 468/500, Train size 1200, Test size 100......
# Training at Epoch 468/500, Batch 1, Cost 1.9468666584472072, Acc 0.8133333333333334. Time 0.06204366683959961
# Epoch 468/500, Train: Cost 1.9468666584472072, Acc 0.8133333333333334; Test: Cost 1.9376095542222482, Acc 0.84. Time 0.0664513111114502
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 469/500, Train size 1200, Test size 100......
# Training at Epoch 469/500, Batch 1, Cost 1.9468567962133596, Acc 0.8133333333333334. Time 0.0619969367980957
# Epoch 469/500, Train: Cost 1.9468567962133596, Acc 0.8133333333333334; Test: Cost 1.9375614891361432, Acc 0.84. Time 0.07128620147705078
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 470/500, Train size 1200, Test size 100......
# Training at Epoch 470/500, Batch 1, Cost 1.9468537053177815, Acc 0.8133333333333334. Time 0.062073469161987305
# Epoch 470/500, Train: Cost 1.9468537053177815, Acc 0.8133333333333334; Test: Cost 1.937495108611298, Acc 0.84. Time 0.0664522647857666
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 471/500, Train size 1200, Test size 100......
# Training at Epoch 471/500, Batch 1, Cost 1.9468564204223626, Acc 0.815. Time 0.06209230422973633
# Epoch 471/500, Train: Cost 1.9468564204223626, Acc 0.815; Test: Cost 1.9376594182998303, Acc 0.84. Time 0.06651186943054199
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 472/500, Train size 1200, Test size 100......
# Training at Epoch 472/500, Batch 1, Cost 1.94686229726821, Acc 0.8116666666666666. Time 0.06205153465270996
# Epoch 472/500, Train: Cost 1.94686229726821, Acc 0.8116666666666666; Test: Cost 1.9374397370433298, Acc 0.84. Time 0.07145905494689941
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 473/500, Train size 1200, Test size 100......
# Training at Epoch 473/500, Batch 1, Cost 1.9468684035371338, Acc 0.815. Time 0.06210756301879883
# Epoch 473/500, Train: Cost 1.9468684035371338, Acc 0.815; Test: Cost 1.9377201648463642, Acc 0.84. Time 0.06650066375732422
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 474/500, Train size 1200, Test size 100......
# Training at Epoch 474/500, Batch 1, Cost 1.9468722589407372, Acc 0.8116666666666666. Time 0.06197404861450195
# Epoch 474/500, Train: Cost 1.9468722589407372, Acc 0.8116666666666666; Test: Cost 1.9374317595711066, Acc 0.84. Time 0.06641316413879395
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 475/500, Train size 1200, Test size 100......
# Training at Epoch 475/500, Batch 1, Cost 1.9468729524489732, Acc 0.815. Time 0.06194496154785156
# Epoch 475/500, Train: Cost 1.9468729524489732, Acc 0.815; Test: Cost 1.9377193616646866, Acc 0.84. Time 0.06870341300964355
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 476/500, Train size 1200, Test size 100......
# Training at Epoch 476/500, Batch 1, Cost 1.9468702864021745, Acc 0.8125. Time 0.06235623359680176
# Epoch 476/500, Train: Cost 1.9468702864021745, Acc 0.8125; Test: Cost 1.937448183634982, Acc 0.84. Time 0.06674742698669434
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 477/500, Train size 1200, Test size 100......
# Training at Epoch 477/500, Batch 1, Cost 1.9468655445945229, Acc 0.815. Time 0.06197857856750488
# Epoch 477/500, Train: Cost 1.9468655445945229, Acc 0.815; Test: Cost 1.9376643886180773, Acc 0.84. Time 0.06638121604919434
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 478/500, Train size 1200, Test size 100......
# Training at Epoch 478/500, Batch 1, Cost 1.9468598425421095, Acc 0.8133333333333334. Time 0.06198620796203613
# Epoch 478/500, Train: Cost 1.9468598425421095, Acc 0.8133333333333334; Test: Cost 1.9374799259628646, Acc 0.84. Time 0.06945538520812988
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 479/500, Train size 1200, Test size 100......
# Training at Epoch 479/500, Batch 1, Cost 1.946854530888416, Acc 0.815. Time 0.06199288368225098
# Epoch 479/500, Train: Cost 1.946854530888416, Acc 0.815; Test: Cost 1.9375864419281152, Acc 0.84. Time 0.0673222541809082
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 480/500, Train size 1200, Test size 100......
# Training at Epoch 480/500, Batch 1, Cost 1.9468502878990543, Acc 0.8141666666666667. Time 0.06185317039489746
# Epoch 480/500, Train: Cost 1.9468502878990543, Acc 0.8141666666666667; Test: Cost 1.937529535602444, Acc 0.84. Time 0.06632280349731445
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 481/500, Train size 1200, Test size 100......
# Training at Epoch 481/500, Batch 1, Cost 1.9468474692950934, Acc 0.8141666666666667. Time 0.061934709548950195
# Epoch 481/500, Train: Cost 1.9468474692950934, Acc 0.8141666666666667; Test: Cost 1.9375180963147884, Acc 0.84. Time 0.06734609603881836
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 482/500, Train size 1200, Test size 100......
# Training at Epoch 482/500, Batch 1, Cost 1.9468460674963173, Acc 0.8141666666666667. Time 0.06201672554016113
# Epoch 482/500, Train: Cost 1.9468460674963173, Acc 0.8141666666666667; Test: Cost 1.9375923621441857, Acc 0.84. Time 0.06691789627075195
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 483/500, Train size 1200, Test size 100......
# Training at Epoch 483/500, Batch 1, Cost 1.9468459858557656, Acc 0.8133333333333334. Time 0.06185746192932129
# Epoch 483/500, Train: Cost 1.9468459858557656, Acc 0.8133333333333334; Test: Cost 1.937464315428403, Acc 0.84. Time 0.06625699996948242
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 484/500, Train size 1200, Test size 100......
# Training at Epoch 484/500, Batch 1, Cost 1.946847201317978, Acc 0.8141666666666667. Time 0.06196856498718262
# Epoch 484/500, Train: Cost 1.946847201317978, Acc 0.8141666666666667; Test: Cost 1.9376592684960048, Acc 0.84. Time 0.07075119018554688
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 485/500, Train size 1200, Test size 100......
# Training at Epoch 485/500, Batch 1, Cost 1.9468498311174935, Acc 0.8125. Time 0.061965227127075195
# Epoch 485/500, Train: Cost 1.9468498311174935, Acc 0.8125; Test: Cost 1.9374092689455564, Acc 0.84. Time 0.06648612022399902
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 486/500, Train size 1200, Test size 100......
# Training at Epoch 486/500, Batch 1, Cost 1.9468543610352247, Acc 0.815. Time 0.061922311782836914
# Epoch 486/500, Train: Cost 1.9468543610352247, Acc 0.815; Test: Cost 1.9377354320310463, Acc 0.84. Time 0.0663142204284668
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 487/500, Train size 1200, Test size 100......
# Training at Epoch 487/500, Batch 1, Cost 1.9468614427248692, Acc 0.8116666666666666. Time 0.06193995475769043
# Epoch 487/500, Train: Cost 1.9468614427248692, Acc 0.8116666666666666; Test: Cost 1.9373469027341574, Acc 0.84. Time 0.06636643409729004
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 488/500, Train size 1200, Test size 100......
# Training at Epoch 488/500, Batch 1, Cost 1.946872684877063, Acc 0.8158333333333333. Time 0.061861276626586914
# Epoch 488/500, Train: Cost 1.946872684877063, Acc 0.8158333333333333; Test: Cost 1.9378436880729288, Acc 0.84. Time 0.06670832633972168
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 489/500, Train size 1200, Test size 100......
# Training at Epoch 489/500, Batch 1, Cost 1.946889623739784, Acc 0.8116666666666666. Time 0.06206774711608887
# Epoch 489/500, Train: Cost 1.946889623739784, Acc 0.8116666666666666; Test: Cost 1.937287962022919, Acc 0.84. Time 0.06650567054748535
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 490/500, Train size 1200, Test size 100......
# Training at Epoch 490/500, Batch 1, Cost 1.946916394086976, Acc 0.8175. Time 0.06188035011291504
# Epoch 490/500, Train: Cost 1.946916394086976, Acc 0.8175; Test: Cost 1.9380167510750657, Acc 0.84. Time 0.06629538536071777
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 491/500, Train size 1200, Test size 100......
# Training at Epoch 491/500, Batch 1, Cost 1.9469547161171266, Acc 0.8108333333333333. Time 0.06201624870300293
# Epoch 491/500, Train: Cost 1.9469547161171266, Acc 0.8108333333333333; Test: Cost 1.9372534381843967, Acc 0.84. Time 0.06859374046325684
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 492/500, Train size 1200, Test size 100......
# Training at Epoch 492/500, Batch 1, Cost 1.9470120912339324, Acc 0.8191666666666667. Time 0.06187081336975098
# Epoch 492/500, Train: Cost 1.9470120912339324, Acc 0.8191666666666667; Test: Cost 1.9382591808407017, Acc 0.85. Time 0.06621122360229492
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 493/500, Train size 1200, Test size 100......
# Training at Epoch 493/500, Batch 1, Cost 1.9470803429254293, Acc 0.8133333333333334. Time 0.06191301345825195
# Epoch 493/500, Train: Cost 1.9470803429254293, Acc 0.8133333333333334; Test: Cost 1.937282845805492, Acc 0.83. Time 0.0662984848022461
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 494/500, Train size 1200, Test size 100......
# Training at Epoch 494/500, Batch 1, Cost 1.9471610094124459, Acc 0.8191666666666667. Time 0.06181001663208008
# Epoch 494/500, Train: Cost 1.9471610094124459, Acc 0.8191666666666667; Test: Cost 1.9384167264146843, Acc 0.85. Time 0.06611394882202148
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 495/500, Train size 1200, Test size 100......
# Training at Epoch 495/500, Batch 1, Cost 1.9472065990247356, Acc 0.8125. Time 0.06205439567565918
# Epoch 495/500, Train: Cost 1.9472065990247356, Acc 0.8125; Test: Cost 1.9373608437780792, Acc 0.83. Time 0.0667412281036377
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 496/500, Train size 1200, Test size 100......
# Training at Epoch 496/500, Batch 1, Cost 1.9472063840886469, Acc 0.8183333333333334. Time 0.061884403228759766
# Epoch 496/500, Train: Cost 1.9472063840886469, Acc 0.8183333333333334; Test: Cost 1.9381533555016899, Acc 0.84. Time 0.06633687019348145
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 497/500, Train size 1200, Test size 100......
# Training at Epoch 497/500, Batch 1, Cost 1.9471163562007452, Acc 0.8125. Time 0.06191134452819824
# Epoch 497/500, Train: Cost 1.9471163562007452, Acc 0.8125; Test: Cost 1.9374272998579736, Acc 0.83. Time 0.06622505187988281
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 498/500, Train size 1200, Test size 100......
# Training at Epoch 498/500, Batch 1, Cost 1.9469892949256702, Acc 0.8158333333333333. Time 0.06204414367675781
# Epoch 498/500, Train: Cost 1.9469892949256702, Acc 0.8158333333333333; Test: Cost 1.937614867312309, Acc 0.84. Time 0.06993818283081055
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 499/500, Train size 1200, Test size 100......
# Training at Epoch 499/500, Batch 1, Cost 1.94687841273721, Acc 0.8158333333333333. Time 0.06179022789001465
# Epoch 499/500, Train: Cost 1.94687841273721, Acc 0.8158333333333333; Test: Cost 1.9376417370629468, Acc 0.84. Time 0.06715559959411621
# =-==-==-==-==-==-==-==-==-==-=
# Training at Epoch 500/500, Train size 1200, Test size 100......
# Training at Epoch 500/500, Batch 1, Cost 1.9468381724684527, Acc 0.8116666666666666. Time 0.06185507774353027
# Epoch 500/500, Train: Cost 1.9468381724684527, Acc 0.8116666666666666; Test: Cost 1.9373538101563652, Acc 0.84. Time 0.06634330749511719
# =-==-==-==-==-==-==-==-==-==-=

# %%
# aggregate dataframe
df_agg = results_df.groupby(["n_train", "step"]).agg(["mean", "std"])
df_agg = df_agg.reset_index()

sns.set_style('whitegrid')
colors = sns.color_palette()
fig, axes = plt.subplots(ncols=2, figsize=(24, 7))

generalization_errors = []

# plot losses and accuracies
for i, n_train in enumerate(train_sizes):
    df = df_agg[df_agg.n_train == n_train]

    dfs = [df.train_cost["mean"], df.test_cost["mean"], df.train_acc["mean"], df.test_acc["mean"]]
    lines = ["o-", "x--", "o-", "x--"]
    labels = [fr"$N={n_train}$", None, fr"$N={n_train}$", None]
    axs = [0,0,1,1]

    for k in range(4):
        ax = axes[axs[k]]
        ax.plot(df.step, dfs[k], lines[k], label=labels[k], markevery=10, color=colors[i], alpha=0.8)


    # plot final loss difference
    #dif = df[df.step == n_epochs].test_cost["mean"] - df[df.step == n_epochs].train_cost["mean"]
    #generalization_errors.append(dif)

# format loss plot
ax = axes[0]
ax.set_title('Train and Test Losses', fontsize=14)
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')

# format generalization error plot
#ax = axes[1]
#ax.plot(train_sizes, generalization_errors, "o-", label=r"$gen(\alpha)$")
#ax.set_xscale('log')
#ax.set_xticks(train_sizes)
#ax.set_xticklabels(train_sizes)
#ax.set_title(r'Generalization Error $gen(\alpha) = R(\alpha) - \hat{R}_N(\alpha)$', fontsize=14)
#ax.set_xlabel('Training Set Size')

# format loss plot
ax = axes[1]
ax.set_title('Train and Test Accuracies', fontsize=14)
ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy')
ax.set_ylim(0.05, 1.05)

legend_elements = [
    mpl.lines.Line2D([0], [0], label=f'N={n}', color=colors[i]) for i, n in enumerate(train_sizes)
    ] + [
    mpl.lines.Line2D([0], [0], marker='o', ls='-', label='Train', color='Black'),
    mpl.lines.Line2D([0], [0], marker='x', ls='--', label='Test', color='Black')
    ]

axes[0].legend(handles=legend_elements, ncol=3)
axes[1].legend(handles=legend_elements, ncol=3)

#axes[1].set_yscale('log', base=2)
plt.show()

# %%
from google.colab import files

# Save the CSV files and the plot to the local file system
results_df.to_csv("my-skdigits_baseline_results.csv")
df_agg.to_csv("my-skdigits_baseline_results_agg.csv")
fig.savefig("my-skdigits_baseline_results.pdf")

# Download the files to your PC
files.download("my-skdigits_baseline_results.csv")
files.download("my-skdigits_baseline_results_agg.csv")
files.download("my-skdigits_baseline_results.pdf")
